# %%
n = 10000
m = 80
std = 30
c = 70 # Limit income
j1 = runif(n,0,m) # Job related feature 1
j2 = runif(n,0,m) # Job related feature 2
eps = rnorm(n,0,std) # Lottery
y = as.numeric(0.3*j1+0.7*j2+eps > c) # Target variable: Income>c?

a = 1-pnorm(c,0,std) 
b = 1-pnorm(c-m,0,std)

# %%
print(a)
print(b)
# Out:
# [1] 0.009815329
# [1] 0.6305587

# %%
data = data.frame(j1,j2,y)

# %%
mylogit = glm(y ~ j1 + j2, family="binomial", data=data)

# %%
preds = predict(mylogit, type="response")

# %%
hist(preds)
# Out:
# Plot with title "Histogram of preds"
